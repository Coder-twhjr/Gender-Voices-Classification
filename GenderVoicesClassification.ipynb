# %% [markdown]
# <a href="https://colab.research.google.com/github/Coder-twhjr/Gender-Voices-Classification/blob/main/GenderVoicesClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gender Voices Classification

# %% [markdown]
# ### Overview
#
# The dataset contains some statistical information about the audio frequencies of different male and female voices. Based on the information provided, you have to find out which voice belongs to which gender using the `RandomForestClassifier` algorithm.
#
# The data description is provided below for the dataset.
#
# <img src='https://student-datasets-bucket.s3.ap-south-1.amazonaws.com/whitehat-ds-datasets/project-4/gender_voice_dataset_attributes.png' width=600>
#
# *Dataset credits: https://www.mldata.io/dataset-details/gender_voice/*
#
# Please note that
#
# 1. In the `label` column, `0` denotes the male class and `1` denotes the female class.
#
# 2. Deploy a prediction model with these attributes as the feature variables and the `label` column as the target variable.
#
# You can get the datasets from the following links:
#
# 1. Train dataset
#
#   https://s3-student-datasets-bucket.whjr.online/whitehat-ds-datasets/project-4/gender-voice-train.csv
#
# 2. Test dataset
#
#   https://s3-student-datasets-bucket.whjr.online/whitehat-ds-datasets/project-4/gender-voice-test.csv

# %% [markdown]
# ---

# %% [markdown]
# ### Project Requirements
#
# 1. Create a pandas DataFrame for the train and test datasets.
#
# 2. Display the first five rows of both the training and test DataFrames.
#
# 3. Display the last five rows of both the training and test DataFrames.
#
# 4. Find the number of rows and columns in the train and test DataFrames.
#
# 5. Check for the missing values in the train and test DataFrames.
#
# 6. Count the number of `male` and `female` classes in the train DataFrame.
#
# 7. Separate the feature variables, i.e., `x_train` and `x_test` from both the DataFrames.
#
# 8. Separate the target variable, i.e., `y_train` and `y_test` from both the DataFrames.
#
# 9. Apply the `RandomForestClassifier` machine learning model to predict the `males` and `female` classes in the test DataFrame, i.e, `x_test`.
#
# 10. Print the confusion matrix and the classification report to evaluate your prediction model. Also, based on the confusion matrix, precision, recall and f1-score values, report whether the prediction model deployed by you is making accurate predictions or not.

# %% [markdown]
# ---

# %% [markdown]
# #### 1. Create The DataFrames

# %%
import pandas as pd

train_df = pd.read_csv('https://s3-student-datasets-bucket.whjr.online/whitehat-ds-datasets/project-4/gender-voice-train.csv')
test_df = pd.read_csv('https://s3-student-datasets-bucket.whjr.online/whitehat-ds-datasets/project-4/gender-voice-test.csv')

# %% [markdown]
# ---

# %% [markdown]
# #### 2. Display First Five Rows

# %%
train_df.head()
# Out:
#    label  meanfreq        sd    median       Q25       Q75       IQR  \
# 0      1  0.235668  0.035568  0.240065  0.222366  0.257763  0.035397
# 1      0  0.190578  0.059717  0.190747  0.151985  0.242259  0.090273
# 2      0  0.202016  0.062551  0.233775  0.133369  0.258403  0.125034
# 3      1  0.236232  0.041141  0.244934  0.227932  0.260342  0.032410
# 4      0  0.189003  0.061455  0.202376  0.135446  0.234851  0.099406
#
#        skew       kurt    sp.ent  ...      mode  centroid   meanfun    minfun  \
# 0  2.006333   6.427613  0.828406  ...  0.242788  0.235668  0.190731  0.047478
# 1  2.727301  13.710214  0.901150  ...  0.186667  0.190578  0.118140  0.047198
# 2  2.132116   7.588438  0.872074  ...  0.262950  0.202016  0.121069  0.046967
# 3  2.175879   7.324086  0.831379  ...  0.243340  0.236232  0.179134  0.049896
# 2120  0.049741  0.274286  0.789062  0.023438  4.359375  4.335938  0.062312
# 2121  0.048096  0.279070  0.813616  0.023438  6.023438  6.000000  0.123384
#
# [5 rows x 21 columns]

# %%
test_df.tail()
# Out:
#       label  meanfreq        sd    median       Q25       Q75       IQR  \
# 1041      0  0.143504  0.073334  0.150426  0.086383  0.197713  0.111330
# 1042      0  0.151532  0.058071  0.151257  0.098246  0.195877  0.097632
# 1043      1  0.230144  0.033577  0.231368  0.222526  0.246105  0.023579
# 1044      0  0.204982  0.061316  0.234010  0.133237  0.254976  0.121739
# 1045      0  0.171713  0.061671  0.189894  0.152660  0.207766  0.055106
#
#           skew       kurt    sp.ent  ...      mode  centroid   meanfun  \
# 1041  3.586009  28.346615  0.961517  ...  0.059947  0.143504  0.090472
# 1042  3.523045  18.652713  0.893303  ...  0.094971  0.151532  0.095423
# 1043  3.413691  17.897104  0.809968  ...  0.229158  0.230144  0.201065
# 1044  1.850012   5.706426  0.867338  ...  0.249565  0.204982  0.120147
# 1045  2.818282  11.990365  0.920936  ...  0.209255  0.171713  0.177866
#
#         minfun    maxfun   meandom    mindom    maxdom   dfrange   modindx
# 1041  0.017448  0.235294  0.462015  0.007812  2.335938  2.328125  0.203020
# 1042  0.056497  0.212766  0.519064  0.087891  0.776367  0.688477  0.650870
# 1043  0.047059  0.279070  1.242622  0.234375  8.648438  8.414062  0.120313
# 1044  0.018161  0.231884  0.408381  0.148438  0.796875  0.648438  0.312048
# 1045  0.027165  0.271186  1.133854  0.031250  5.789062  5.757812  0.198301
#
# [5 rows x 21 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### 4. Rows & Columns In Train DataFrame

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (2122, 21)
# (1046, 21)

# %% [markdown]
# ---

# %% [markdown]
# #### 5. Check For Missing Values

# %%
train_df.isnull().sum()
# Out:
# label       0
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# label       0
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### 6. Count The `male` & `female` Classes

# %%
train_df['label'].value_counts()
# Out:
# 1    1085
# 0    1037
# Name: label, dtype: int64

# %%
test_df['label'].value_counts()
# Out:
# 0    547
# 1    499
# Name: label, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### 7. Feature Variables Extraction

# %%
x_train = train_df.iloc[:, 1:]
x_train.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.235668  0.035568  0.240065  0.222366  0.257763  0.035397  2.006333
# 1  0.190578  0.059717  0.190747  0.151985  0.242259  0.090273  2.727301
# 2  0.202016  0.062551  0.233775  0.133369  0.258403  0.125034  2.132116
# 3  0.236232  0.041141  0.244934  0.227932  0.260342  0.032410  2.175879
# 4  0.189003  0.061455  0.202376  0.135446  0.234851  0.099406  1.620451
#
#         kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   6.427613  0.828406  0.177183  0.242788  0.235668  0.190731  0.047478
# 1  13.710214  0.901150  0.370874  0.186667  0.190578  0.118140  0.047198
# 2   7.588438  0.872074  0.283257  0.262950  0.202016  0.121069  0.046967
# 3   7.324086  0.831379  0.235322  0.243340  0.236232  0.179134  0.049896
# 4   6.374442  0.928735  0.472934  0.215050  0.189003  0.114454  0.047856
#
#      maxfun   meandom    mindom     maxdom    dfrange   modindx
# 0  0.279070  1.240513  0.023438   9.140625   9.117188  0.087997
# 1  0.279070  1.262109  0.023438   4.757812   4.734375  0.194908
# 2  0.277457  0.898143  0.023438   8.460938   8.437500  0.085771
# 3  0.274286  1.379012  0.023438  10.617188  10.593750  0.103917
# 4  0.271186  1.147995  0.023438   5.953125   5.929688  0.119684

# %%
x_test = test_df.iloc[:, 1:]
x_test.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.186833  0.027472  0.184325  0.173955  0.204731  0.030777  2.655225
# 1  0.188879  0.060316  0.195537  0.138072  0.242975  0.104904  1.497393
# 2  0.150705  0.087127  0.174299  0.069666  0.226082  0.156416  2.603951
# 3  0.183667  0.040607  0.182534  0.156480  0.207646  0.051166  2.054138
# 4  0.205159  0.039543  0.210805  0.186667  0.228908  0.042241  2.099683
#
#         kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0  10.565846  0.821812  0.159883  0.180645  0.186833  0.172790  0.023495
# 1   5.037085  0.909425  0.374225  0.140386  0.188879  0.133092  0.050847
# 2  22.328899  0.969287  0.781729  0.050181  0.150705  0.109992  0.017260
# 3   7.483019  0.898138  0.313925  0.177040  0.183667  0.149237  0.018648
# 4   7.562209  0.876002  0.271880  0.224885  0.205159  0.154736  0.047105
#
#      maxfun   meandom    mindom     maxdom    dfrange   modindx
# 0  0.271186  0.178571  0.007812   0.226562   0.218750  0.108929
# 1  0.272727  0.855938  0.023438   8.718750   8.695312  0.098712
# 2  0.266667  1.240954  0.007812   5.562500   5.554688  0.332396
# 3  0.262295  0.550312  0.007812   3.421875   3.414062  0.166503
# 4  0.277457  1.578835  0.187500  10.804688  10.617188  0.113644

# %% [markdown]
# ---

# %% [markdown]
# #### 8. Target Variable Extraction

# %%
y_train = train_df.iloc[:, 0]
y_train.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: label, dtype: int64

# %%
y_test = test_df.iloc[:, 0]
y_test.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: label, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# #### 9. Building A Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

rfc = RandomForestClassifier(n_jobs=-1)
rfc.fit(x_train, y_train)
rfc.score(x_train, y_train)
# Out:
# 1.0

# %%
y_pred = rfc.predict(x_test)
print(y_pred)
# Out:
# [1 0 0 ... 1 0 1]

# %% [markdown]
# ---

# %% [markdown]
# #### 10. Confusion Matrix & Classification Report

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[531,  16],
#        [  6, 493]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       547
#            1       0.97      0.99      0.98       499
#
#     accuracy                           0.98      1046
#    macro avg       0.98      0.98      0.98      1046
# weighted avg       0.98      0.98      0.98      1046

# %% [markdown]
# - Interpretation 1: All the three parameters, i.e., `precision, recall` and `f1-score` values are very close to `1`. This means the prediction model is very accurate and it can be used to make predictions on a new dataset.

# %% [markdown]
# ---
